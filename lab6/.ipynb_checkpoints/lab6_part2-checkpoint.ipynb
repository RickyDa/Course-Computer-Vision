# %%
# !pip install -q albumentations

# %%
import torch
from matplotlib import pyplot as plt
import torchvision
from torch.utils.data import Dataset, DataLoader
import numpy as np
from numpy.random import randint
from typing import Dict, List
import cv2
import glob
import os

from albumentations import (
    HorizontalFlip, IAAPerspective, ShiftScaleRotate, CLAHE, RandomRotate90,
    Transpose, ShiftScaleRotate, Blur, OpticalDistortion, GridDistortion, HueSaturationValue,
    IAAAdditiveGaussianNoise, GaussNoise, MotionBlur, MedianBlur, RandomBrightnessContrast, IAAPiecewiseAffine,
    IAASharpen, IAAEmboss, Flip, OneOf, Compose
)

# %%
def dataset_to_dict(data_images,data_labels) -> Dict[int,List[np.ndarray]]:
    '''
    Turns dataset into dictionary

    # Returns
        Dictionary where the labels are the keys and data stored on each entry as a list og numpy.ndarray
    '''
    numbers = {}
    for img, label in zip(data_images, data_labels):
        if label not in numbers.keys():
            numbers[label] = []
        numbers[label] += [img]

    return numbers

def build_dataset(numbers:dict, to_tensor=True, amount:int=10):
    '''
    turns Mnist dataset into new dataset of numbers [0-100]
    '''
    data = None
    targets = np.array([])
    print('Building: 0',end='')
    for hundreds,tens,unit in np.ndindex(2,10,10):
        target = 100*hundreds + 10*tens + unit
        if(target > 100):      
            break
        nset = np.array([])
        while len(nset) < amount:
            r_unit, r_tens, r_hundreds = randint(0, len(numbers[unit])), randint(0,len(numbers[tens])), randint(0,len(numbers[hundreds]))
            permutation = np.concatenate([numbers[hundreds][r_hundreds],numbers[tens][r_tens],numbers[unit][r_unit]], axis=1)
            if nset.size == 0:    
                nset = permutation.reshape([1,28,84])
            else:
                nset = np.append(nset, [permutation], axis=0)
                
            if len(nset) % amount == 0:
                nset = np.unique(nset,axis=0) # to ensure there are no redundent permutation of an image    
        if data is None:
            data = nset
        else:
            data = np.append(data, nset, axis=0)
        targets = np.append(targets, np.ones(amount)*target, axis=0).astype(int)
        print('.', end='')
    print("100\nDone!")
    if to_tensor:
        return  torch.from_numpy(data), torch.from_numpy(targets)
    return data,targets

# %%
train_set = torchvision.datasets.MNIST(root='',download=True)
data_images = train_set.data.numpy()
data_labels = train_set.targets.numpy()
numbers = dataset_to_dict(data_images,data_labels)
train, targets = build_dataset(numbers,amount=10)
# Out:
# Building: 0.....................................................................................................100
# Done!

# %%
def augmentations(p=1,blur_limit=3):
    return Compose([
        OneOf([
            IAAAdditiveGaussianNoise(),
            GaussNoise(),
        ], p=0.2),
        OneOf([
            MotionBlur(p=.2),
            MedianBlur(blur_limit=blur_limit, p=0.1),
            Blur(blur_limit=blur_limit, p=0.1),
        ], p=0.2),
        ShiftScaleRotate(shift_limit=0.0625, scale_limit=0.05, rotate_limit=(-15,15),border_mode=cv2.BORDER_REPLICATE, p=0.5),
        OneOf([
            OpticalDistortion(p=0.3),
            GridDistortion(p=.1),
            IAAPiecewiseAffine(p=0.3),
        ], p=0.2),
        OneOf([
            IAASharpen(),
            IAAEmboss(),         
        ], p=0.3),
    ], p=p)


class MNISTDataset(Dataset):

    def __init__(self, X_train, y_train, transforms=None, preprocessing=None):
        super(MNISTDataset,self).__init__()
        self.X_train = X_train
        self.y_train = y_train
        self.classes = torch.unique(y_train)
        self.transforms = transforms
        self.preprocessing = preprocessing

    def __getitem__(self,idx):
        x = self.X_train[idx]
        y = self.y_train[idx]
        if self.transforms != None:
            x = self.transforms(image=x.numpy())
            x = x['image']

        return x, y

    def __len__(self):
        return len(self.X_train)
    


def plot_data(images, labels, size):
    cols = 5
    rows = int((batch_size/cols) + 1)
    plt.figure(figsize=[20,10])
    for index,(img,label) in enumerate(zip(images, labels)):
        plt.subplot(rows,cols,index+1)
        plt.imshow(img,cmap = 'gray')
        plt.title(label.numpy())
        plt.axis('off')
    plt.show()

# %%
batch_size = 20
aug = augmentations()
mnist_dataset = MNISTDataset(train, targets,transforms=aug)
mnist_dataloader = DataLoader(mnist_dataset,batch_size=batch_size,shuffle=True,num_workers=4)

# %%
batch = iter(mnist_dataloader)
images, labels = next(batch)
plot_data(images, labels, batch_size)

# %% [markdown]
# # Pre-process for data segmentaion task
# Images and segments were taken from https://www.kaggle.com/solesensei/solesensei_bdd100k
#
# ### BDD100K Tracking Challenge for CVPR 2020 Workshop on Autonomous Driving
#
# https://bdd-data.berkeley.edu/

# %%
images_path = sorted(glob.glob('/content/drive/My Drive/Colab Notebooks/CV/images and segs/Images/*.jpg'))
segs_path = sorted(glob.glob('/content/drive/My Drive/Colab Notebooks/CV/images and segs/Segs/*.png'))
images = np.array([plt.imread(img) for img in images_path])
masks = np.array([plt.imread(seg) for seg in segs_path])

# %%
class BDD100KDataset(Dataset):

    def __init__(self, images, masks, transforms=None, preprocessing=None):
        super(BDD100KDataset, self).__init__()
        self.images = images
        self.masks = masks
        self.transforms = transforms
        self.preprocessing = preprocessing

    def __getitem__(self,idx):
        image = self.images[idx]
        mask = self.masks[idx]
        if self.transforms != None:
            result = self.transforms(image=image,mask=mask)
            image = result['image']
            mask = result['mask']
        return torch.from_numpy(image), torch.from_numpy(mask)

    def __len__(self):
        return len(self.images)

# %%
batch_size = 4
aug = augmentations(blur_limit=40)
bdd100k_dataset = BDD100KDataset(images, masks,transforms=aug)
bdd100k_dataloader = DataLoader(bdd100k_dataset, batch_size=batch_size, shuffle=True, num_workers=4)

# %%
batch = iter(bdd100k_dataloader)
images, labels = next(batch)

# %%
cell = 1
rows = len(images)
cols = 4
plt.figure(figsize=[30,20])
for index,(img,mask) in enumerate(zip(images,labels)):
    plt.subplot(rows,cols,cell)
    plt.imshow(img)
    plt.title(f"Image: {index+1}")
    plt.subplot(rows,cols,cell+1)
    plt.imshow(mask,cmap='gray')
    plt.title(f"mask: {index+1}")
    cell+=2
plt.show()
